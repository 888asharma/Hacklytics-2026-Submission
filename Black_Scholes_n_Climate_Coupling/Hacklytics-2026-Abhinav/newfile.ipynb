# %%
def america(given_list):
    for i in range(len(given_list)):
        given_list[i] = "america"
    return given_list

list = [2223, "fiejf", 89, "fewijfwei"]
america(list)
# Out:
# ['america', 'america', 'america', 'america']
